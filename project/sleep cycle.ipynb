# %% [markdown]
# # Management of Chul Hyoung Park's sleep cycle
# ## 1. 규칙적인 기상 시간 (주말에도 10시 이전 기상)
# ## 2. 수면 보충하지 않고, 1시 30분 이전에는 침대에 눕지 않기. 수면 효율을 점차 높여가기
# ## 3. 매일 30분 이상의 운동 하기
# ## 4. 낮잠은 오후 4시 이전 45분 이하로 매일 자기
# ## 5. 이완 반응으로 긴장이 완화되게 내버려두어라

# %%
### 이완 반응
# 눈을 감고 전신의 긴장을 풀기
# 복식 호흡
# 둔감해지기 (생각을 비우기)
# 하루 10~15분 이완 반응에 투자하기

# %%
### 인지 재구성
# 인지 재구성 일기를 쓰고 열 가지 관점 전환 질문하기
# 친구한테 말하듯 나 자신에게 말해줌으로써 관점을 전환하라
# 과거를 돌이켜 봄으로써 상상과 실제 결과의 괴리를 객관적으로 인식하라
# 스트레스 받는 상황에 마주하면 부정적 자동 사고가 떠오르기 전 스스로에게 멈춰라고 말하고 미니 이완 반응 하기

# %% [markdown]
# ### 60seconds sleep diary

# %%
import pandas as pd
date='2020.05.25'
Daily0525 = pd.DataFrame({"1. 지난 밤 당신은 몇 시에 잠자리에 들었는가?": ['00:45'],
                                 '2. 불을 끈 것은 몇 시였는가?': ['00:45'],
                                 '3. 밤중에 대략 몇 번이나 잠에서 깼는가?': [2],
                                 '4. 잠이 들 때까지 걸린 시간은?': ['1시간'],
                                 '5. 오늘 아침 최종적으로 깬 시간은?': ['08:35'],
                                 '6. 잠자리에서 나온 것은 몇 시?': ['08:35'],
                                 '7. 간밤에 약 몇 시간 잤나?': ['3시간 30분'],
                                 '8. 수면의 질 (1~5)': [1],
                                 '9. 복용한 수면제?': ['각 1알 씩'],
                                 '10. 수면에 대한 긍정적 생각': ['3시간 잤으니까 됐다. 내일 하루 잘 버티면 앞으로 불면에 대한 두려움이 사라질 것'],
                                 '11. 수면에 대한 부정적 생각': ['사업 프로젝트, 학과세미나, 논문 작업, 서울대발표 등 할게 너무 많아서 못 자면 안 된다']})
Daily0525=Daily0525.T
Daily0525.columns=[date]

# %%
#Standardized document
date='2020.05.26'
Daily0526=pd.DataFrame({"1. 지난 밤 당신은 몇 시에 잠자리에 들었는가?": ['00:30'],
                 '2. 불을 끈 것은 몇 시였는가?': ['00:30'],
                 '3. 밤중에 대략 몇 번이나 잠에서 깼는가?': [0],
                 '4. 잠이 들 때까지 걸린 시간은?': ['30분'],
                 '5. 오늘 아침 최종적으로 깬 시간은?': ['8:00'],
                 '6. 잠자리에서 나온 것은 몇 시?': ['8:30'],
                 '7. 간밤에 약 몇 시간 잤나?': ['7시간 30분'],
                 '8. 수면의 질 (1~5)': [5],
                 '9. 복용한 수면제?': ['없음'],
                 '10. 수면에 대한 긍정적 생각': ['잡념을 버리고, 이완반응을 연습할 기회다'],
                 '11. 수면에 대한 부정적 생각': ['오늘도 못 자면 내일은 오늘보다 더 힘들텐데']})
Daily0526=Daily0526.T
Daily0526.columns=[date]

# %%
#Standardized document
date='2020.06.04'
Daily0604=pd.DataFrame({"1. 지난 밤 당신은 몇 시에 잠자리에 들었는가?": ['11:15'],
                 '2. 불을 끈 것은 몇 시였는가?': ['11:30'],
                 '3. 밤중에 대략 몇 번이나 잠에서 깼는가?': [0],
                 '4. 잠이 들 때까지 걸린 시간은?': ['15분'],
                 '5. 오늘 아침 최종적으로 깬 시간은?': ['8:10'],
                 '6. 잠자리에서 나온 것은 몇 시?': ['8:35'],
                 '7. 간밤에 약 몇 시간 잤나?': ['8시간 25분'],
                 '8. 수면의 질 (1~5)': [5],
                 '9. 복용한 수면제?': ['1일분'],
                 '10. 수면에 대한 긍정적 생각': ['산책을 오래 하니 잘 잘 수 있을 것 같은 느낌'],
                 '11. 수면에 대한 부정적 생각': ['오늘은 잘 수 있을까']})
Daily0604=Daily0604.T
Daily0604.columns=[date]

# %%
#Standardized document
date='2020.06.04'
Daily0526=pd.DataFrame({"1. 지난 밤 당신은 몇 시에 잠자리에 들었는가?": ['a'],
                 '2. 불을 끈 것은 몇 시였는가?': ['a'],
                 '3. 밤중에 대략 몇 번이나 잠에서 깼는가?': [1],
                 '4. 잠이 들 때까지 걸린 시간은?': ['a'],
                 '5. 오늘 아침 최종적으로 깬 시간은?': ['a'],
                 '6. 잠자리에서 나온 것은 몇 시?': ['a'],
                 '7. 간밤에 약 몇 시간 잤나?': ['a'],
                 '8. 수면의 질 (1~5)': [1],
                 '9. 복용한 수면제?': ['a'],
                 '10. 수면에 대한 긍정적 생각': ['a'],
                 '11. 수면에 대한 부정적 생각': ['a']})
Daily0526=Daily0526.T
Daily0526.columns=[date]

# %%
DailyDiary=pd.concat([Daily0525, Daily0526, Daily0604], axis=1)

# %%
DailyDiary
# Out:
#                                                                     2020.05.25  \
# 1. 지난 밤 당신은 몇 시에 잠자리에 들었는가?                                              00:45
# 2. 불을 끈 것은 몇 시였는가?                                                       00:45
# 3. 밤중에 대략 몇 번이나 잠에서 깼는가?                                                     2
# 4. 잠이 들 때까지 걸린 시간은?                                                        1시간
# 5. 오늘 아침 최종적으로 깬 시간은?                                                    08:35
# 6. 잠자리에서 나온 것은 몇 시?                                                      08:35
# 7. 간밤에 약 몇 시간 잤나?                                                      3시간 30분
# 8. 수면의 질 (1~5)                                                               1
# 9. 복용한 수면제?                                                             각 1알 씩
# 10. 수면에 대한 긍정적 생각               3시간 잤으니까 됐다. 내일 하루 잘 버티면 앞으로 불면에 대한 두려움이 사라질 것
# 11. 수면에 대한 부정적 생각            사업 프로젝트, 학과세미나, 논문 작업, 서울대발표 등 할게 너무 많아서 못 자면 ...
#
# ...
